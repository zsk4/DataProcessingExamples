# %%
from sliderule import icesat2
import matplotlib.pyplot as plt
from pyproj import CRS, Transformer

region = [ {"lon": -160, "lat": -84},
           {"lon": -160, "lat": -85},
           {"lon": -150, "lat": -85},
           {"lon": -150, "lat": -84},
           {"lon": -160, "lat": -84} ]

icesat2.init("slideruleearth.io", True)
parms = {
    "poly": region,
    "srt": icesat2.SRT_LAND,
    "cnf": icesat2.CNF_SURFACE_HIGH,
    "ats": 10.0,
    "cnt": 10,
    "len": 40.0,
    "res": 20.0,
    "t0": "2019-01-01T00:00:00Z",
    "t1": "2019-01-25T00:00:00Z"
}
rsps = icesat2.atl06p(parms)
print(rsps)
# Out:
#                                n_fit_photons  cycle  spot  pflags  \
# time
# 2019-01-01 08:18:05.588571136            409      2     5       0
# 2019-01-01 08:18:05.591397888            397      2     5       0
# 2019-01-01 08:18:05.594225408            387      2     5       0
# 2019-01-01 08:18:05.597050368            396      2     5       0
# 2019-01-01 08:18:05.599874560            399      2     5       0
# ...                                      ...    ...   ...     ...
# 2019-01-24 22:05:11.844576768            387      2     1       0
# 2019-01-24 22:05:11.847377152            394      2     1       0
# 2019-01-24 22:05:11.850160384            328      2     1       0
# 2019-01-24 22:05:11.852940288            252      2     1       0
# 2019-01-24 22:05:11.855719680            285      2     1       0
#
#                                w_surface_window_final      h_mean  \
# time
# 2019-01-01 08:18:05.588571136                     3.0  129.938678
# 2019-01-01 08:18:05.591397888                     3.0  129.847063
# 2019-01-01 08:18:05.594225408                     3.0  129.749209
# 2019-01-01 08:18:05.597050368                     3.0  129.620542
# 2019-01-01 08:18:05.599874560                     3.0  129.460997
# ...                                               ...         ...
# 2019-01-24 22:05:11.844576768                     3.0  119.582107
# 2019-01-24 22:05:11.847377152                     3.0  119.532816
# 2019-01-24 22:05:11.850160384                     3.0  119.457533
# 2019-01-24 22:05:11.852940288                     3.0  119.372855
# 2019-01-24 22:05:11.855719680                     3.0  119.299248
#
#                                      y_atc       x_atc  rgt  dh_fit_dx  \
# time
# 2019-01-01 08:18:05.588571136 -2626.719727  29565866.0   59  -0.004277
# 2019-01-01 08:18:05.591397888 -2626.763672  29565886.0   59  -0.004778
# 2019-01-01 08:18:05.594225408 -2626.791260  29565906.0   59  -0.005221
# 2019-01-01 08:18:05.597050368 -2626.798828  29565926.0   59  -0.007775
# 2019-01-01 08:18:05.599874560 -2626.788818  29565946.0   59  -0.007556
# ...                                    ...         ...  ...        ...
# 2019-01-24 22:05:11.844576768  3741.320068  30740144.0  419  -0.002868
# 2019-01-24 22:05:11.847377152  3741.256836  30740164.0  419  -0.001405
# 2019-01-24 22:05:11.850160384  3741.264893  30740184.0  419  -0.005199
# 2019-01-24 22:05:11.852940288  3741.310791  30740204.0  419  -0.004165
# 2019-01-24 22:05:11.855719680  3741.368164  30740224.0  419  -0.005422
#
#                                 h_sigma  region  rms_misfit  segment_id  gt  \
# time
# 2019-01-01 08:18:05.588571136  0.005987      11    0.120932     1477285  50
# 2019-01-01 08:18:05.591397888  0.005646      11    0.112447     1477286  50
# 2019-01-01 08:18:05.594225408  0.005643      11    0.110753     1477287  50
# 2019-01-01 08:18:05.597050368  0.006127      11    0.121453     1477288  50
# 2019-01-01 08:18:05.599874560  0.006658      11    0.132855     1477289  50
# ...                                 ...     ...         ...         ...  ..
# 2019-01-24 22:05:11.844576768  0.008451      11    0.166083     1536305  10
# 2019-01-24 22:05:11.847377152  0.008075      11    0.160286     1536306  10
# 2019-01-24 22:05:11.850160384  0.009702      11    0.172916     1536307  10
# 2019-01-24 22:05:11.852940288  0.010169      11    0.158099     1536308  10
# 2019-01-24 22:05:11.855719680  0.008382      11    0.138567     1536309  10
#
#                                                    geometry
# time
# 2019-01-01 08:18:05.588571136  POINT (-150.00081 -84.76524)
# 2019-01-01 08:18:05.591397888   POINT (-150.00158 -84.7654)
# 2019-01-01 08:18:05.594225408  POINT (-150.00234 -84.76556)
# 2019-01-01 08:18:05.597050368   POINT (-150.0031 -84.76573)
# 2019-01-01 08:18:05.599874560  POINT (-150.00387 -84.76589)
# ...                                                     ...
# 2019-01-24 22:05:11.844576768  POINT (-152.04354 -84.01576)
# 2019-01-24 22:05:11.847377152  POINT (-152.04411 -84.01559)
# 2019-01-24 22:05:11.850160384  POINT (-152.04468 -84.01542)
# 2019-01-24 22:05:11.852940288  POINT (-152.04526 -84.01525)
# 2019-01-24 22:05:11.855719680  POINT (-152.04583 -84.01508)
#
# [163874 rows x 16 columns]

# %%
from pyproj import CRS, Transformer
def ll2xy(lon, lat):
    """
    Transform coordinates from input geodetic coordinates (lon, lat)
    to output Antarctic Polar Stereographic coordinates (x, y)
    Can also take lists of floats!

    Parameters
    lon - Geodetic longitude in EPSG:4326 [float]
    lat - Geodetic latitude in EPSG:4326 [float]

    Returns
    x - Antarctic Polar Stereographic (EPSG:3031) x [float]
    y - Antarctic Polar Stereographic (EPSG:3031) y [float]
    """
    
    crs_ll = CRS("EPSG:4326")
    crs_xy = CRS("EPSG:3031")
    ll_to_xy = Transformer.from_crs(crs_ll, crs_xy, always_xy = True)
    x, y = ll_to_xy.transform(lon, lat)
    return x, y

# %%
x,y = ll2xy(rsps['geometry'].x, rsps['geometry'].y)
plt.scatter(x,y,c=rsps['h_mean']) #in xy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x,y = ll2xy(rsps['geometry'].x, rsps['geometry'].y)
#       2 plt.scatter(x,y,c=rsps['h_mean']) #in xy
#
# NameError: name 'rsps' is not defined
